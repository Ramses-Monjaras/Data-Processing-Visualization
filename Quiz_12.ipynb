# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramses-Monjaras/Data-Processing-Visualization/blob/main/Quiz_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pa
from bs4 import BeautifulSoup

headers = {'User-Agent': 'Mozilla/5.0'}
r = requests.get('https://en.wikipedia.org/wiki/SpongeBob_SquarePants', headers=headers)
html_contents = r.text
html_soup = BeautifulSoup(html_contents,"lxml")

# %%
tables = html_soup.find_all('table')
len(tables)
# Out:
# 18

# %%
from io import StringIO
import pandas as pa

df = pa.read_html(StringIO(str(tables)))[2]
df.columns = df.columns.droplevel(0)

df
# Out:
#     Season                    Region 1                 Region 2  \
# 0        1       October 28, 2003[112]    November 7, 2005[113]
# 1        2       October 19, 2004[115]    October 23, 2006[116]
# 2        3     September 27, 2005[118]    December 3, 2007[119]
# 3        4     September 12, 2006[121]    November 3, 2008[122]
# 4        4        January 9, 2007[124]    November 3, 2008[122]
# 5        5      September 4, 2007[125]   November 16, 2009[126]
# 6        5      November 18, 2008[128]   November 16, 2009[126]
# 7        6       December 8, 2009[129]   November 29, 2010[130]
# 8        6       December 7, 2010[132]   November 29, 2010[130]
# 9        7       December 6, 2011[133]  September 17, 2012[134]
# 10       8         March 12, 2013[137]    October 28, 2013[138]
# 11       9       October 10, 2017[140]                      TBA
# 12      10       October 15, 2019[142]                      TBA
# 13      11    March 31, 2020[144][145]                      TBA
# ...
