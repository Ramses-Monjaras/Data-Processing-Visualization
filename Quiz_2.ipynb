# %% [markdown]
# #Lie to Me

# %% [markdown]
# ![Fox_welfare-jobs-ff-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The lie factor of this graph is that it is visually showing that people on welfare is significantly more than people with a full time job. However, the actual data shows that there is only a difference of 6.9 million, which is not too far off from each other. I believe that Fox News created the graph like this, is to mislead people and make them think that there are a lot more people that is on welfare compared to people with a full time job.
