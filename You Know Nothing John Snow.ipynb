# %% [markdown]
# #You Know Nothing John Snow

# %% [markdown]
# 1. This graph has everything labeled which includes the streets and buildings making it easier to understand which building is which. This graph shows all the pumps in affected areas which tells you that the cholera is waterborne
#
#
# 2. Here is a world population pyramid: [World Population Pyramid](https://www.populationpyramid.net/world/)

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# This graph shows excellence because it display the information neatly and you know what information the graph is trying to convey. The graph is also color coded and labled, so you know the left side is male and the right side is female. The graph also shows revelent information like age and population percentage.
