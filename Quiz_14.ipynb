# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramses-Monjaras/Data-Processing-Visualization/blob/main/Quiz_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdfplumber
import pdfplumber
import pandas as pd

# %%
from google.colab import files
import os

uploaded = files.upload()

pdf_path = list(uploaded.keys())[0]
print(f"PDF path: {pdf_path}")
# Out:
#      <input type="file" id="files-10f2452d-de22-4e35-b5d5-a3c51fe37666" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10f2452d-de22-4e35-b5d5-a3c51fe37666">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with pdfplumber.open(pdf_path) as pdf:
  page = pdf.pages[0]

  table_data = page.extract_table()

  print(table_data)
# Out:
# [['Expenditure by function £ million', None, '2009/10', '2010/11 1'], ['Policy functions', 'Financial', '22.5', '30.57'], [None, 'Information 2', '10.2', '14.8'], [None, 'Contingency', '2.6', '1.2'], ['Remunerated functions', 'Agency services 3', '44.7', '35.91'], [None, 'Payments', '22.41', '19.88'], [None, 'Banking', '22.90', '44.23'], [None, 'Other', '12.69', '10.32']]

# %%
if table_data:
  df = pd.DataFrame(table_data[1:], columns=table_data[0])
  print(df)
# Out:
#   Expenditure by function £ million               None 2009/10 2010/11 1
# 0                  Policy functions          Financial    22.5     30.57
# 1                              None      Information 2    10.2      14.8
# 2                              None        Contingency     2.6       1.2
# 3             Remunerated functions  Agency services 3    44.7     35.91
# 4                              None           Payments   22.41     19.88
# 5                              None            Banking   22.90     44.23
# 6                              None              Other   12.69     10.32
